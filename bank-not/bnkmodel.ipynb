# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("BankNote_Authentication.csv")

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,make_scorer
score=accuracy_score(y_test,y_predict) 
print(score)
# Out:
# 0.9854545454545455

# %%
import pickle
pickle_out=open("classifier.pkl","wb")
pickle.dump(classifier,pickle_out)
pickle_out.close
# Out:
# <function BufferedWriter.close>

# %%
classifier.predict([[2,3,4,1]])
# Out:
# c:\Users\natsu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- ------------
# absl-py                      2.1.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# blinker                      1.8.2
# cachetools                   5.3.2
# certifi                      2023.11.17
# charset-normalizer           3.3.2
# click                        8.1.7
# colorama                     0.4.6
# comm                         0.2.2
# comtypes                     1.4.6
# contourpy                    1.2.1
# cycler                       0.12.1
# debugpy                      1.8.2
# decorator                    5.1.1
# distlib                      0.3.8
# dm-tree                      0.1.8
# executing                    2.0.1
# filelock                     3.15.4
# Flask                        3.0.3
# flatbuffers                  23.5.26
# fonttools                    4.53.1
# gast                         0.5.4
# google-auth                  2.27.0
# google-auth-oauthlib         1.2.0
# google-pasta                 0.2.0
# grpcio                       1.60.0
# h5py                         3.10.0
# idna                         3.6
# ipykernel                    6.29.5
# ipython                      8.26.0
# itsdangerous                 2.2.0
# jedi                         0.19.1
# Jinja2                       3.1.4
# joblib                       1.4.2
# jupyter_client               8.6.2
# jupyter_core                 5.7.2
# keras                        2.15.0
# kiwisolver                   1.4.5
# libclang                     16.0.6
# Markdown                     3.5.2
# markdown-it-py               3.0.0
# MarkupSafe                   2.1.4
# matplotlib                   3.9.1
# matplotlib-inline            0.1.7
# mdurl                        0.1.2
# ml-dtypes                    0.2.0
# mpmath                       1.3.0
# namex                        0.0.7
# nest-asyncio                 1.6.0
# numpy                        1.26.4
# oauthlib                     3.2.2
# opt-einsum                   3.3.0
# packaging                    23.2
# pandas                       2.2.2
# parso                        0.8.4
# patsy                        0.5.6
# pillow                       10.4.0
# pip                          24.2
# platformdirs                 4.2.2
# prompt_toolkit               3.0.47
# protobuf                     4.23.4
# psutil                       6.0.0
# pure-eval                    0.2.2
# pyasn1                       0.5.1
# pyasn1-modules               0.3.0
# PyAudio                      0.2.14
# Pygments                     2.17.2
# pyparsing                    3.1.2
# pypiwin32                    223
# python-dateutil              2.8.2
# pyttsx3                      2.91
# pytz                         2023.3.post1
# pywin32                      306
# pyzmq                        26.0.3
# requests                     2.31.0
# requests-oauthlib            1.3.1
# rich                         13.7.0
# rsa                          4.9
# scikit-learn                 1.5.1
# scipy                        1.14.0
# seaborn                      0.13.2
# setuptools                   69.0.3
# six                          1.16.0
# SpeechRecognition            3.10.4
# stack-data                   0.6.3
# statsmodels                  0.14.2
# sympy                        1.12
# tensorboard                  2.15.1
# tensorboard-data-server      0.7.2
# tensorflow                   2.15.0
# tensorflow-estimator         2.15.0
# tensorflow-intel             2.15.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# threadpoolctl                3.5.0
# tornado                      6.4.1
# traitlets                    5.14.3
# typing_extensions            4.9.0
# tzdata                       2023.4
# urllib3                      2.1.0
# virtualenv                   20.26.3
# wcwidth                      0.2.13
# Werkzeug                     3.0.1
# wheel                        0.42.0
# wrapt                        1.14.1
# Note: you may need to restart the kernel to use updated packages.
